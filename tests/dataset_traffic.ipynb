# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from scipy.io import arff
plt.style.use("bmh")

# %%
DATA_PATH = "../data/Traffic/"
data_train = np.array(pd.read_table(DATA_PATH + "TRAFFIC_TRAIN.tsv"))
data_test = np.array(pd.read_table(DATA_PATH + "TRAFFIC_TEST.tsv"))
data_train.shape, data_test.shape
# Out:
# ((467, 192), (467, 192))

# %%
plt.figure(figsize=(30, 5))
for i, idx in enumerate(np.random.randint(len(data_train), size=5), 1):
    plt.subplot(1, 5, i)
    plt.plot(data_train[idx])
plt.show()
