# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from scipy.io import arff
plt.style.use("bmh")

# %%
DATA_PATH = "../data/InsectSound/"
data_train = pd.DataFrame(arff.loadarff(DATA_PATH + "InsectSound_TRAIN.arff")[0])
data_test = pd.DataFrame(arff.loadarff(DATA_PATH + "InsectSound_TEST.arff")[0])
data_train.head()
# Out:
#        att1          att2      att3      att4      att5      att6      att7  \
# 0  0.000153 -6.578439e-05  0.000038 -0.000029  0.000020 -0.000006  0.000004
# 1 -0.000029  6.673935e-07  0.000035 -0.000119 -0.000141 -0.000131 -0.000251
# 2 -0.019499  4.194278e-02  0.192660  0.232282  0.132188  0.013040 -0.035715
# 3  0.000000  0.000000e+00  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.000023 -7.772223e-05  0.000111 -0.000096  0.000043  0.000023 -0.000083
#
#        att8      att9     att10  ...    att592    att593    att594    att595  \
# 0  0.000002  0.000003 -0.000003  ... -0.000003  0.000010 -0.000006 -0.000006
# 1 -0.000253 -0.000261 -0.000309  ...  0.001548  0.001509  0.001564  0.001499
# 2 -0.066381 -0.070153 -0.050134  ...  0.087443  0.234516  0.242373  0.130852
# 3  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 4  0.000119 -0.000104  0.000058  ... -0.000201 -0.000108 -0.000037  0.000045
#
# ...

# %%
X_train = np.array(data_train.drop("target", axis=1), dtype=float)[:, 200:500]
y_train = np.array(data_train["target"])

X_test = np.array(data_test.drop("target", axis=1) , dtype=float)[:, 200:500]
y_test = np.array(data_test["target"])

X_train.shape, X_test.shape
# Out:
# ((25000, 300), (25000, 300))

# %%
for y in np.unique(y_train):
    plt.figure(figsize=(30, 5))
    print(y)
    Xy_train = X_train[y_train == y]
    for i, idx in enumerate(np.random.randint(len(Xy_train), size=5), 1):
        plt.subplot(1, 5, i)
        plt.plot(np.arange(200, 500), Xy_train[idx])
    plt.show()
# Out:
# b'Aedes_female'
# b'Aedes_male'
# b'Fruit_flies'
# b'House_flies'
# b'Quinx_female'
# b'Quinx_male'
# b'Stigma_female'
# b'Stigma_male'
# b'Tarsalis_female'
# b'Tarsalis_male'
